# %% [markdown]
# # Загрузка данных.
#
# Подключение необходимых библиотек.

# %%
import numpy as np # библиотека для эффективной работы с данными
import pandas as pd # библиотека для работы с наборами данных
import matplotlib.pyplot as plt # библиотека для визуализации
import seaborn as sns # еще одна библиотека для построения графиков

# %% [markdown]
# Используем набор данных "Данные быстрых свиданий": https://www.kaggle.com/annavictoria/speed-dating-experiment

# %%
data = pd.read_csv('C:\\Users\\Admin\\Desktop\\Speed_Dating_Data.csv', encoding = "ISO-8859-1")

# %% [markdown]
# # Первичный анализ данных.
#
# Узнаем размеры таблицы:

# %%
data.shape
# Out:
# (8378, 195)

# %% [markdown]
# Таким образом, наша таблица состоит из 8378 строк(объектов) и 195 столбцов(признаков).
#
# Выведем первые и последние 5 строк нашей таблицы:

# %%
data.head() # первые 5 записей
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# ...

# %%
data.tail() # последние 5 записей
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 8373  552  22.0       1   44       2    21     22        14      10.0      5
# 8374  552  22.0       1   44       2    21     22        13      10.0      4
# 8375  552  22.0       1   44       2    21     22        19      10.0     10
# 8376  552  22.0       1   44       2    21     22         3      10.0     16
# 8377  552   NaN       1   44       2    21     22         2      10.0     15
#
#       ...  attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  \
# 8373  ...      8.0      5.0       7.0     6.0     7.0      9.0      5.0
# 8374  ...      8.0      5.0       7.0     6.0     7.0      9.0      5.0
# 8375  ...      8.0      5.0       7.0     6.0     7.0      9.0      5.0
# 8376  ...      8.0      5.0       7.0     6.0     7.0      9.0      5.0
# 8377  ...      8.0      5.0       7.0     6.0     7.0      9.0      5.0
#
#       intel5_3  fun5_3  amb5_3
# 8373       9.0     5.0     6.0
# ...

# %% [markdown]
# # Выделение подмножества и работа с ним.

# %% [markdown]
# Так как признаков очень много, выделим некоторое подмножество с 14 признаками, наиболее подходящими для анализа данных.
#
# Описание признаков, использующихся в подмножестве:
#
# 1) gender - Пол участника (женский = 0, мужской = 1).
# 2) dec – Решение участника (Если да - 1, если нет, то 0).
# 3) age - Возраст участника.
# 4) samerace – Принадлежность общей расе.
# 5) goal - Основная цель участия в этом мероприятии.
# 6) career_c - Род деятельности.
# 7) date - Часто ли участник ходит на свидания?
# 8) like - В целом, насколько вам нравится этот человек?
# 9) attr1_1 – Привлекательность (насколько важно это качество в партнере)
# 10) sinc1_1 - Искренность (насколько важно это качество в партнере)
# 11) intel1_1 - Интеллектуальность (насколько важно это качество в партнере)
# 12) fun1_1 – Чувство юмора (насколько важно это качество в партнере)
# 13) amb1_1 - Амбициозность (насколько важно это качество в партнере)
# 14) shar1_1 – Общие интересы (насколько важно это качество в партнере)

# %%
data_subset = data.loc[:,data.columns.isin(['gender', 'dec', 'age', 'samerace','goal', 'career_c', 'date','like','attr1_1', 
'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1'])]

data_subset.head()
# Out:
#    gender  samerace   age  goal  date  career_c  attr1_1  sinc1_1  intel1_1  \
# 0       0         0  21.0   2.0   7.0       NaN     15.0     20.0      20.0
# 1       0         0  21.0   2.0   7.0       NaN     15.0     20.0      20.0
# 2       0         1  21.0   2.0   7.0       NaN     15.0     20.0      20.0
# 3       0         0  21.0   2.0   7.0       NaN     15.0     20.0      20.0
# 4       0         0  21.0   2.0   7.0       NaN     15.0     20.0      20.0
#
#    fun1_1  amb1_1  shar1_1  dec  like
# 0    15.0    15.0     15.0    1   7.0
# 1    15.0    15.0     15.0    1   7.0
# 2    15.0    15.0     15.0    1   7.0
# 3    15.0    15.0     15.0    1   7.0
# 4    15.0    15.0     15.0    1   6.0

# %% [markdown]
# Чтобы вывести информацию по столбцам, воспользуемся методом data.info(). Он выводит информацию о наборе данных (сколько ненулевых значений у каждого признака и какого типа значения присутствуют в признаке).

# %%
data_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   gender    8378 non-null   int64
#  1   samerace  8378 non-null   int64
#  2   age       8283 non-null   float64
#  3   goal      8299 non-null   float64
#  4   date      8281 non-null   float64
#  5   career_c  8240 non-null   float64
#  6   attr1_1   8299 non-null   float64
#  7   sinc1_1   8299 non-null   float64
#  8   intel1_1  8299 non-null   float64
#  9   fun1_1    8289 non-null   float64
#  10  amb1_1    8279 non-null   float64
#  11  shar1_1   8257 non-null   float64
#  12  dec       8378 non-null   int64
#  13  like      8138 non-null   float64
# dtypes: float64(11), int64(3)
# memory usage: 916.5 KB

# %% [markdown]
# *В выбранном подмножестве содержатся пропуски в столбцах: age; goal; date; career_c; attr1_1; sinc1_1; intel1_1; fun1_1; amb1_1; shar1_1; like.*
#
# - В age количество пустых значений: 8378 – 8283 = 95;
# - В goal количество пустых значений: 8378 – 8299 = 79;
# - В date количество пустых значений: 8378 – 8281 = 97;
# - В career_c количество пустых значений: 8378 – 8240 = 138;
# - В attr1_1 количество пустых значений: 8378 – 8299 = 79;
# - В sinc1_1 количество пустых значений: 8378 – 8299 = 79;
# - В intel1_1 количество пустых значений: 8378 – 8299 = 79;
# - В fun1_1 количество пустых значений: 8378 – 8289 = 89;
# - В amb1_1 количество пустых значений: 8378 – 8279 = 99;
# - В shar1_1 количество пустых значений: 8378 – 8257 = 121;
# - В like количество пустых значений: 8378 – 8138 = 240.
#
# Всего объектов с пропусками: 1195.
#
#
# Посмотрим на статистики численных данных:

# %%
data_subset.describe() # статистический анализ числовых столбцов
# Out:
#             gender     samerace          age         goal         date  \
# count  8378.000000  8378.000000  8283.000000  8299.000000  8281.000000
# mean      0.500597     0.395799    26.358928     2.122063     5.006762
# std       0.500029     0.489051     3.566763     1.407181     1.444531
# min       0.000000     0.000000    18.000000     1.000000     1.000000
# 25%       0.000000     0.000000    24.000000     1.000000     4.000000
# 50%       1.000000     0.000000    26.000000     2.000000     5.000000
# 75%       1.000000     1.000000    28.000000     2.000000     6.000000
# max       1.000000     1.000000    55.000000     6.000000     7.000000
#
#           career_c      attr1_1      sinc1_1     intel1_1       fun1_1  \
# count  8240.000000  8299.000000  8299.000000  8299.000000  8289.000000
# mean      5.277791    22.514632    17.396389    20.265613    17.457043
# std       3.309520    12.587674     7.046700     6.783003     6.085239
# ...

# %% [markdown]
# Отсюда видно, что **категориальным признаком** является признак career_c (Род занятия участника).
# Там встречаются только целые цифры от 0 до 17.
# Как раз таки career_c является столбцом с максимальным количеством уникальных значений категориального признака (максимальное значение 17).

# %% [markdown]
# Также из результата команды data_subset.describe() можно увидеть, какие **бинарные признаки** присутствуют в нашем подмножестве. Это признаки gender (пол участника, где женщины = 0, мужчины = 1), dec (решение участника, где 1 - если да, 0 - если нет), samerace (принадлежность общей расе, где 1 - если участники принадлежат, 0 - если нет).

# %% [markdown]
# # Нормализация переменных.

# %% [markdown]
# Проведем нормализацию переменных для подмножества.
# Для начала преобразуем все вещественные признаки через стандартное отклонение и удалим все строки с пустыми значениями.

# %%
data_set = data_subset

# Нормализация признаков через стандартное отклонение

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_set[['age', 'goal', 'career_c', 'date','like','attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1']] = pd.DataFrame(scaler.fit_transform(data_set[['age', 'goal', 'career_c', 'date','like','attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1']]), columns = data_set[['age', 'goal', 'career_c', 'date','like','attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1']].columns)

data_set = data_set.dropna() # Удаление строк с пустыми значениями

data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7930 entries, 30 to 8377
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   gender    7930 non-null   int64
#  1   samerace  7930 non-null   int64
#  2   age       7930 non-null   float64
#  3   goal      7930 non-null   float64
#  4   date      7930 non-null   float64
#  5   career_c  7930 non-null   float64
#  6   attr1_1   7930 non-null   float64
#  7   sinc1_1   7930 non-null   float64
#  8   intel1_1  7930 non-null   float64
#  9   fun1_1    7930 non-null   float64
#  10  amb1_1    7930 non-null   float64
#  11  shar1_1   7930 non-null   float64
#  12  dec       7930 non-null   int64
#  13  like      7930 non-null   float64
# dtypes: float64(11), int64(3)
# memory usage: 929.3 KB
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17640\2343929014.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# **Есть ли на ваш взгляд выбросы, аномальные значения?**
#
# Найдем СКО для каждого из значений набора данных.
# Для этого создадим массив массивов features_std, который содержит стандартные отклонения каждого элемента датасета. При
# прохождении по этому массиву будем считать, что значение аномально, если его стандартное отклонение по модулю больше 3-х.

# %%
data_subset_1 = data_subset

# Заменяем пустые значения на среднее значение стобцов
for col in data_subset_1.columns:
    data_subset_1[col].fillna(data_subset_1[col].mean(), inplace=True)
    
# Нормализация признаков через стандартное отклонение
from sklearn.preprocessing import StandardScaler

scale_features_std = StandardScaler()
features_std = scale_features_std.fit_transform(data_subset_1[['age', 'goal', 'date','like',
                                                             'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1',
                                                             'amb1_1', 'shar1_1']])

# Ищем выбросы (аномальные значения). Будем считать, что значение аномально, если его стандартное отклонение >= 3 по модулю.
for j in range(0, 10):
     for i in range(0, 8378):
         if abs(features_std[i][j]) >= 3:
             print(j, i)
# Out:
# 0 1404
# 0 1405
# 0 1406
# 0 1407
# 0 1408
# 0 1409
# 0 1410
# 0 1411
# 0 1412
# 0 1413
# 0 1414
# 0 1415
# 0 1416
# 0 1417
# 0 1418
# 0 1419
# 0 1420
# 0 1421
# 0 1881
# 0 1882
# 0 1883
# 0 1884
# 0 1885
# 0 3328
# 0 3329
# 0 3330
# 0 3331
# 0 3332
# 0 3333
# 0 3334
# 0 3335
# 0 3336
# 0 3337
# 0 3338
# 0 3339
# 0 3340
# 0 3341
# 0 3342
# 0 3343
# 0 3344
# 0 3345
# 0 3346
# 0 3347
# 0 5744
# 0 5745
# 0 5746
# 0 5747
# 0 5748
# 0 5749
# 0 5750
# 0 5751
# 0 5752
# 0 5753
# 0 5754
# 0 5755
# 0 5756
# 0 5757
# 0 5758
# 0 5759
# 0 5760
# 0 5761
# 0 5762
# 0 6822
# 0 6823
# 0 6824
# 0 6825
# 0 6826
# 0 6827
# 3 844
# 3 846
# 3 1152
# 3 5312
# 3 5857
# 3 6880
# 3 7412
# 3 8298
# 4 190
# 4 191
# 4 192
# 4 193
# 4 194
# 4 195
# 4 196
# 4 197
# 4 198
# 4 199
# 4 1826
# 4 1827
# 4 1828
# 4 1829
# 4 1830
# 4 1831
# 4 1832
# 4 1833
# 4 1834
# 4 1835
# 4 3471
# 4 3472
# 4 3473
# 4 3474
# 4 3475
# 4 3476
# 4 3477
# 4 3478
# 4 3479
# 4 5624
# 4 5625
# 4 5626
# 4 5627
# 4 5628
# 4 5629
# 4 5630
# ...

# %% [markdown]
# После применения кода, выясняем, что аномальные значения присутствуют в столбцах: age, like, attr1_1, sinc1_1, intel1_1, fun1_1, amb1_1.

# %% [markdown]
# **Столбец с максимальным средним значением после нормировки признаков через стандартное отклонение?**
#
# Для нахождения столбца с максимальным средним значением после нормировки признаков через стандартное отклонение пробежимся по всем строкам столбца, посчитаем сумму всех значений, а затем поделим на количество измерений, а после сравним каждое среднее арифметическое столбцов.

# %%
for i in range(0, 10):
    s = 0
    for j in range(0, 8378):
        s += features_std[j][i]
    s = s / 8378
    print(i, s)
# Out:
# 0 -2.0696555527450654e-15
# 1 -2.1944728202187386e-16
# 2 1.0304481068853207e-15
# 3 1.0274267312632805e-15
# 4 -1.5606200186686015e-15
# 5 -9.146817146303033e-16
# 6 1.2191515667881881e-17
# 7 6.261403427254553e-17
# 8 3.989965038558577e-15
# 9 -1.4489351338328315e-15

# %% [markdown]
# **Столбцом с максимальным средним значением после нормировки признаков через стандартное отклонение в выбранном подмножестве оказался столбец fun1_1. Его среднее значение после нормировки признаков через стандартное отклонение равно 6.261403427254553e-17.**

# %% [markdown]
# **Столбцом с целевым признаком** является столбец решение участника – dec.

# %% [markdown]
# **Сколько объектов попадает в тренировочную выборку при использовании train_test_split с параметрами test_size = 0.3, random_state = 42?**

# %%
target = data_set.dec # Выделяем целевую переменную
train = data_set.drop(['dec'], axis=1)

from sklearn.model_selection import train_test_split

# Выделяем тренировочную и тестовую выборки с параметрами test_size = 0.3, random_state = 42

x_train, x_test, y_train, y_test = train_test_split(train, target, test_size = 0.3, random_state = 42)

N_train, _ = x_train.shape 
N_test, _ = x_test.shape 
print(N_train)
# Out:
# 5551

# %% [markdown]
# *Таким образом в тренировочную выборку с параметрами test_size = 0.3, random_state = 42 попадает 5551 объектов.*

# %% [markdown]
# **Между какими признаками наблюдается линейная зависимость (корреляция)?**

# %% [markdown]
# Выявить корреляцию между признаками позволяет команда data_subset.corr(). Чем ниже будет наше значение, тем сильнее между признаками будет заметна отрицательная корреляция (то есть с увеличением одной переменной, другая будет уменьшаться), чем выше будет наше значение, тем сильнее будет заметна положительная корреляция (то есть с увеличением одной переменной, другая будет также увеличиваться).

# %%
data_subset.corr()
# Out:
#             gender  samerace       age      goal      date  career_c  \
# gender    1.000000 -0.000966  0.070172  0.025826 -0.100422 -0.006199
# samerace -0.000966  1.000000  0.007107  0.016986 -0.040665 -0.019897
# age       0.070172  0.007107  1.000000  0.089463  0.006793  0.015300
# goal      0.025826  0.016986  0.089463  1.000000  0.050627  0.033265
# date     -0.100422 -0.040665  0.006793  0.050627  1.000000 -0.074637
# career_c -0.006199 -0.019897  0.015300  0.033265 -0.074637  1.000000
# attr1_1   0.350533  0.019679  0.028380  0.045680 -0.184665  0.086846
# sinc1_1  -0.127583 -0.050765  0.028697  0.056153  0.179638 -0.094665
# intel1_1 -0.107492  0.023160  0.043889  0.024065 -0.004293 -0.098946
# fun1_1    0.050396  0.033425 -0.085887 -0.015626  0.011425  0.036101
# amb1_1   -0.346886 -0.027135 -0.085240 -0.088439  0.083984  0.028393
# shar1_1  -0.133232 -0.014923  0.016907 -0.095333  0.088432  0.004487
# like      0.075765  0.038150  0.026809  0.046785 -0.035919 -0.087566
#
# ...

# %% [markdown]
# Для наглядности лучше вывести температурную таблицу корреляции признаков.

# %%
plt.figure(figsize=(12,10), dpi= 70)
sns.heatmap(data_subset.corr(), xticklabels=data_subset.corr().columns, yticklabels=data_subset.corr().columns, 
cmap='RdYlGn', center=0, annot=True)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# В выбранном подмножестве отрицательная корреляция наблюдается между признака-ми:
#
# - *amb1_1 и gender* (Из определения данного выше, мы узнаем, что с увеличением значения амбициозности, значение пола будет уменьшаться. Это значит, что женщины придают большое внимание амбициозности мужского пола и наобо-рот.)
# - *attr1_1 и shar 1_1* (Из определения данного выше, мы узнаем, что с увеличени-ем значения привлекательности, значение общих интересов будет уменьшаться. Это значит, что участники, отдавшие большее количество баллов привлека-тельности, отдают меньше баллов общим интересам и наоборот.)
# - *amb1_1 и attr1_1* (Из определения данного выше, мы узнаем, что с увеличением значения амбициозности, значение привлекательности будет уменьшаться. Это значит, что участники, отдавшие большее количество баллов привлекательно-сти, отдают меньше баллов амбициозности и наоборот.)
# - *attr1_1 и sinc1_1* (Из определения данного выше, мы узнаем, что с увеличением значения привлекательности, значение искренности будет уменьшаться. Это значит, что участники, отдавшие большее количество баллов привлекательно-сти, отдают меньше баллов искренности и наоборот.)
#
#
# Положительная корреляция в выбранном подмножестве наблюдается между призна-ками: *attr1_1 и gender* (Из определения данного выше, мы узнаем, что с увеличением значения привлекательности, значение пола будет увеличиваться. Это значит, что мужчинам очень важно, чтобы противоположный пол был привлекательным).

# %% [markdown]
# **Сколько признаков достаточно для объяснения 90% дисперсии после применения метода PCA?**

# %%
from sklearn.decomposition import PCA
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
pca = PCA()
pca.fit(x_train)
X_pca = pca.transform(x_train)

# %%
for i, component in enumerate(pca.components_):
     print("{} component: {}% of initial variance".format(i + 1, round(100 * pca.explained_variance_ratio_[i], 2)))
     print(" + ".join("%.3f x %s" % (value, name) for value, name in zip(component,train.columns)))
# Out:
# 1 component: 17.62% of initial variance
# 0.148 x gender + 0.015 x samerace + 0.053 x age + 0.105 x goal + -0.242 x date + 0.103 x career_c + 0.641 x attr1_1 + -0.328 x sinc1_1 + -0.166 x intel1_1 + 0.057 x fun1_1 + -0.436 x amb1_1 + -0.392 x shar1_1 + 0.041 x like
# 2 component: 11.25% of initial variance
# 0.040 x gender + -0.000 x samerace + 0.410 x age + 0.389 x goal + 0.173 x date + -0.360 x career_c + 0.006 x attr1_1 + 0.349 x sinc1_1 + 0.322 x intel1_1 + -0.361 x fun1_1 + -0.334 x amb1_1 + -0.106 x shar1_1 + 0.203 x like
# 3 component: 10.26% of initial variance
# -0.032 x gender + 0.019 x samerace + 0.126 x age + -0.213 x goal + -0.403 x date + 0.028 x career_c + -0.016 x attr1_1 + -0.439 x sinc1_1 + 0.631 x intel1_1 + -0.371 x fun1_1 + 0.080 x amb1_1 + 0.119 x shar1_1 + -0.160 x like
# 4 component: 10.08% of initial variance
# ...

# %% [markdown]
# Результат работы метода:
#
# - 1 признак объясняет 17.62% дисперсии
# - 2 признака объясняют 11.25% дисперсии
# - 3 признака объясняют 10.26% дисперсии
# - 4 признака объясняют 10.08% дисперсии
# - 5 признаков объясняют 9.24% дисперсии
# - 6 признаков объясняют 8.42% дисперсии
# - 7 признаков объясняют 8.02% дисперсии
# - 8 признаков объясняют 7.62% дисперсии
# - 9 признаков объясняют 6.97% дисперсии
# - 10 признаков объясняют 6.6% дисперсии
#
# **Значит, девяти признаков хватит для объяснения 90% дисперсии после применения метода PCA.**

# %% [markdown]
# *Для наглядности покажем график зависимости доли объяснённой дисперсии от числа компонент*

# %%
plt.figure(figsize=(10,7))
plt.plot(np.cumsum(pca.explained_variance_ratio_), color='k', lw=2)
plt.axhline(0.9, c='r')
plt.axvline(3.2, c='b')

# %% [markdown]
# *Какой признак вносит наибольший вклад в первую компоненту?*
#
# Посмотрим на распределение вклада признаков в первую компоненту и выявим самый большой коэффициент. Признак с самым большим коэффициентом и будет вносить наибольший вклад в первую компоненту.
#
# *Самым высоким коэффициентом стала 1 у признака order, а это значит, что именно он вносит наибольший вклад в первую компоненту.*

# %% [markdown]
# **Построить двухмерное представление данных с помощью алгоритма t-SNE. На
# сколько кластеров визуально, на ваш взгляд, разделяется выборка? Объяснить
# смысл кластеров.**

# %%
from sklearn.manifold import TSNE

# %%
tsne1 = TSNE(learning_rate=200, random_state=130)
transformed1 = tsne1.fit_transform(train)
x_axist1 = transformed1[:, 0]
y_axist1 = transformed1[:, 1]
plt.scatter(x_axist1, y_axist1, c=target)
plt.show()

# %% [markdown]
# Визуально можно выделить 3 кластера.
